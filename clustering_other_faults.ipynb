# %% [markdown]
# #### Applied Machine Learning and Data Engineering in Business Context
#
# Final Project
#
# December 1, 2021
#
# ### Steel Plate Fault Detection
#
# Alisa Ilina
# Anurag Singh
# Eirik Egge
# Henry Stoll
# Magnus Eliassen
# Olivia Lundholm

# %% [markdown]
# ## Clustering

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

from sklearn.preprocessing import RobustScaler
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing

from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans, AgglomerativeClustering, FeatureAgglomeration
from sklearn.metrics import silhouette_samples, silhouette_score
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###### DF Other Faults Only

# %%
df = spark.sql("SELECT * from steel_faults")
df = df.toPandas()
df = df.loc[df['Other_Faults'] == 1]
df = df.drop(['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'id', 'labels', 'Other_Faults'], axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Unsupervised Methods 'Other Faults' = 1

# %% [markdown]
# ##### K-Means

# %% [markdown]
# ###### Silhouette Score

# %%
def sil_score(df, k_max):
    coeffs={}
    for i in range(2, k_max+1):
        clusters = KMeans(n_clusters=i)
        clusters.fit(df)
        labels = clusters.labels_
        sil_coeff = metrics.silhouette_score(df, labels, metric='euclidean')
        coeffs[i] = sil_coeff
    return f'Optimal k = {max(coeffs, key=coeffs.get)} yields a silhouette score of {round(max(coeffs.values()),3)}'
sil_score(df, 8)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: &#39;Optimal k = 2 yields a silhouette score of 0.759&#39;</div>

# %% [markdown]
# ###### Elbow Method

# %%
sse = []
list_k = list(range(1, 10))
for k in list_k:
    km = KMeans(n_clusters=k)
    km.fit(df)
    sse.append(km.inertia_)
# Plot sse against k
plt.figure(figsize=(10, 6))
plt.plot(list_k, sse, '-o')
plt.xlabel(r'Number of clusters *k*')
plt.ylabel('Sum of squared distance');

# %%
# elbow method suggests k = 3
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###### K-Means

# %%
kmeans = KMeans(n_clusters=8, random_state=0)
kmeans.fit(df)
df['cluster_kmeans'] = kmeans.labels_
print(df['cluster_kmeans'].value_counts())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0    246
# 6    125
# 3    107
# 4     76
# 7     49
# 1     28
# 2     16
# 5     14
# Name: cluster_kmeans, dtype: int64
# </div>

# %%
#most important features for other faults (ref. 'explain')
cols = [
'Y_Minimum',
'Y_Maximum',
'Steel_Plate_Thickness',
'Edges_Y_Index',
'Pixels_Areas',
'Minimum_of_Luminosity',
'Length_of_Conveyer',
'Edges_Index',
'Maximum_of_Luminosity',
'Empty_Index',
'Edges_X_Index']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###### Steel Plate Dimensions

# %% [markdown]
# Comment:
#  * Majority of 'Other Faults' contists of Steel Type A400 (ref.nb.: 'explain')
#    * Most important feature for distinguishing between common v. other faults
#  * Other faults can be clustered in three groups based on Y Dimensions
#    * Distance bewteen c1 & c2 is kind of overlapping
#    * Distance between (c1,c2) & c3 is clear

# %%
print(df['TypeOfSteel_A400'].value_counts()) #majority is steel A400 (the MIF for 'Other_Faults')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1    402
# 0    259
# Name: TypeOfSteel_A400, dtype: int64
# </div>

# %%
sns.scatterplot(y = 'X_Maximum', x = 'Y_Minimum', hue='cluster_agg_clust', data = df)

# %%
names = ['X_Maximum', 'X_Minimum', 'Y_Minimum', 'Y_Maximum']
fig, axes = plt.subplots(2,2)
fig.set_size_inches(18.5, 10.5, forward=True)
# Iterating through axes and names
for name, ax in zip(names, axes.flatten()):
    sns.scatterplot(y = name, x = 'Y_Minimum', hue='cluster_kmeans', data = df, ax=ax)

# %%
sns.pairplot(data=df, hue="cluster_kmeans", vars=cols, corner=True);

# %% [markdown]
# ##### Agglomerative Clustering

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram

def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)#df = df.drop('cluster_kmeans', axis = 1)
    
    
    
agg_clust = AgglomerativeClustering(n_clusters=8, linkage = 'ward').fit(df) #same result as k-means
df['cluster_agg_clust'] = agg_clust.labels_
df['cluster_agg_clust'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[115]: 4    201
# 3    116
# 7     95
# 5     79
# 6     61
# 2     54
# 0     39
# 1     16
# Name: cluster_agg_clust, dtype: int64</div>

# %%
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)

model = model.fit(df)
plot_dendrogram(model, truncate_mode="level", p=3)

# %%
display(agg_clust)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">Exception</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-349352039010677&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>display<span class="ansi-blue-fg">(</span>agg_clust<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python_shell/scripts/PythonShellImpl.py</span> in <span class="ansi-cyan-fg">display</span><span class="ansi-blue-fg">(self, input, *args, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1046</span>             self<span class="ansi-blue-fg">.</span>displayHTML<span class="ansi-blue-fg">(</span>input<span class="ansi-blue-fg">.</span>_repr_html_<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1047</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">-&gt; 1048</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">raise</span> Exception<span class="ansi-blue-fg">(</span>genericErrorMsg<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1049</span>
# <span class="ansi-green-intense-fg ansi-bold">   1050</span>     <span class="ansi-green-fg">def</span> displayHTML<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> html<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">Exception</span>: Cannot call display(&lt;class &#39;sklearn.cluster._agglomerative.AgglomerativeClustering&#39;&gt;)
#  Call help(display) for more info.</div>

# %%
sns.swarmplot(y = 'Y_Minimum', x = 'cluster_agg_clust', data = df)

# %% [markdown]
# ##### Feature Agglomeration

# %%
f_agg_clust = FeatureAgglomeration(n_clusters=3).fit(df) 
df['cluster_f_agg_clust'] = agg_clust.labels_
df['cluster_f_agg_clust'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: 0    606
# 2     39
# 1     16
# Name: cluster_f_agg_clust, dtype: int64</div>

# %%
sns.swarmplot(y = 'Y_Minimum', x = 'cluster_f_agg_clust', data = df)

# %% [markdown]
# ##### Correlation Analysis of Clusters

# %%
df_corr = df.drop(['cluster_kmeans', 'cluster_agg_clust', 'cluster_f_agg_clust'], axis = 1)
df_dum = pd.get_dummies(df.cluster_agg_clust)
df_corr = pd.concat([df_in, df_dum], axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2205308288263973&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> df_corr <span class="ansi-blue-fg">=</span> df<span class="ansi-blue-fg">.</span>drop<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#39;cluster_kmeans&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;cluster_agg_clust&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#39;cluster_f_agg_clust&#39;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> axis <span class="ansi-blue-fg">=</span> <span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> df_dum <span class="ansi-blue-fg">=</span> pd<span class="ansi-blue-fg">.</span>get_dummies<span class="ansi-blue-fg">(</span>df<span class="ansi-blue-fg">.</span>cluster_agg_clust<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>df_corr <span class="ansi-blue-fg">=</span> pd<span class="ansi-blue-fg">.</span>concat<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span>df_in<span class="ansi-blue-fg">,</span> df_dum<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span> axis<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;df_in&#39; is not defined</div>

# %% [markdown]
# #### Radar Plot All Labels

# %%
df_mc = spark.sql('SELECT * from default.steel_faults_oversampled_multiclass')
df_mc = df_mc.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cols = [
'Y_Minimum',
'Y_Maximum',
'Steel_Plate_Thickness',
'Edges_Y_Index',
'Pixels_Areas',
'Minimum_of_Luminosity',
'Length_of_Conveyer',
'Edges_Index',
'Maximum_of_Luminosity',
'Empty_Index',
'Edges_X_Index',
'labels']

mif = [
'TypeOfSteel_A400',
'Square_Index',
'Y_Minimum',
'Minimum_of_Luminosity',
'Steel_Plate_Thickness',
'Y_Perimeter',
'Edges_X_Index',
'Length_of_Conveyer',
'Orientation_Index',
'LogOfAreas',
'X_Minimum',
'labels']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_mc = df_mc[mif] #keep most important features only
X = df_mc.drop(['labels'], axis = 1)
y = df_mc.labels.to_numpy() #series to array -> scale_to_df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def scale_to_df(X,y,df):
    X = MinMaxScaler().fit_transform(X) 
    data = np.hstack((X, y.reshape(-1,1)))
    return pd.DataFrame(data, columns = df.columns)

df_mc = scale_to_df(X,y, df_mc)
target_names = ['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']
target_names_1 = ['Other_Faults', 'Bumps']
target_names_2 = ['Bumps', 'Other_Faults']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def plot_radar(df, target_names):
    avg_df = df.groupby("labels").mean()
    fig = go.Figure()

    for i in range(len(target_names)):
        fig.add_trace(
                    go.Scatterpolar(
                                    r=avg_df.loc[i].values,
                                    theta=avg_df.columns,
                                    fill='toself',
                                    name=target_names[i],
                                    showlegend=True,
                                    )
                    )

    fig.update_layout(
        polar=dict(
            radialaxis=dict(
                            visible=True,
                            range=[0, 1]
                        )
                ),
        #title="Radar Plot Most Important Features"
        title="Radar Plot For Feature Importance"
    )

    fig.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plot_radar(df_mc, target_names)

# %%
plot_radar(df_mc, target_names_2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-221209454811735&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>plot_radar<span class="ansi-blue-fg">(</span>df_mc<span class="ansi-blue-fg">,</span> target_names_2<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;target_names_2&#39; is not defined</div>

# %%
# Overlapping Labels
# 'Pastry' & 'Stains'
# 'Z_Scratch' & 'Dirtiness'

sep = [
'TypeOfSteel_A400',
'Square_Index',
'Y_Minimum',
'Minimum_of_Luminosity',
'Steel_Plate_Thickness',
'Y_Perimeter',
'Edges_X_Index',
'Length_of_Conveyer',
'Orientation_Index',
'LogOfAreas',
'X_Minimum]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-cyan-fg">  File </span><span class="ansi-green-fg">&#34;&lt;command-3211499312531064&gt;&#34;</span><span class="ansi-cyan-fg">, line </span><span class="ansi-green-fg">16</span>
# <span class="ansi-red-fg">    &#39;X_Minimum]</span>
#                ^
# <span class="ansi-red-fg">SyntaxError</span><span class="ansi-red-fg">:</span> EOL while scanning string literal
# </div>

# %%
def plot_radar(df, target_names):    
    avg_df = df.groupby("labels").mean()
    fig = go.Figure()

    for i in range(len(target_names)):
        fig.add_trace(
                    go.Scatterpolar(
                                    r=avg_df.loc[i].values,
                                    theta=avg_df.columns,
                                    fill='toself',
                                    name=target_names[i],
                                    showlegend=True,
                                    )
                    )
        
    layout=go.Layout(updatemenus=list([dict(buttons= list_updatemenus)]))

    fig.update_layout(
        polar=dict(
            radialaxis=dict(
                            visible=True,
                            range=[0, 1]
                        )
                ),
        #title="Radar Plot Most Important Features"
        title="Radar Plot For Feature Importance - Uncommon Faults"
    )

    fig.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ModuleNotFoundError</span>                       Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-221209454811737&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">from</span> plotly<span class="ansi-blue-fg">.</span>offline <span class="ansi-green-fg">import</span> init_notebook_mode<span class="ansi-blue-fg">,</span>iplot
# <span class="ansi-green-intense-fg ansi-bold">      2</span> <span class="ansi-green-fg">import</span> plotly<span class="ansi-blue-fg">.</span>graph_objects <span class="ansi-green-fg">as</span> go
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span><span class="ansi-green-fg">import</span> cufflinks <span class="ansi-green-fg">as</span> cf
# <span class="ansi-green-intense-fg ansi-bold">      4</span> init_notebook_mode<span class="ansi-blue-fg">(</span>connected<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>
#
# <span class="ansi-green-fg">/databricks/python_shell/dbruntime/PythonPackageImportsInstrumentation/__init__.py</span> in <span class="ansi-cyan-fg">import_patch</span><span class="ansi-blue-fg">(name, globals, locals, fromlist, level)</span>
# <span class="ansi-green-intense-fg ansi-bold">    156</span>             <span class="ansi-red-fg"># Import the desired module. If you’re seeing this while debugging a failed import,</span>
# <span class="ansi-green-intense-fg ansi-bold">    157</span>             <span class="ansi-red-fg"># look at preceding stack frames for relevant error information.</span>
# <span class="ansi-green-fg">--&gt; 158</span><span class="ansi-red-fg">             </span>original_result <span class="ansi-blue-fg">=</span> python_builtin_import<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">,</span> globals<span class="ansi-blue-fg">,</span> locals<span class="ansi-blue-fg">,</span> fromlist<span class="ansi-blue-fg">,</span> level<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    159</span>
# <span class="ansi-green-intense-fg ansi-bold">    160</span>             is_root_import <span class="ansi-blue-fg">=</span> thread_local<span class="ansi-blue-fg">.</span>_nest_level <span class="ansi-blue-fg">==</span> <span class="ansi-cyan-fg">1</span>
#
# <span class="ansi-red-fg">ModuleNotFoundError</span>: No module named &#39;cufflinks&#39;</div>

# %%
plot_radar(df_mc, target_names)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-221209454811738&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>plot_radar<span class="ansi-blue-fg">(</span>df_mc<span class="ansi-blue-fg">,</span> target_names<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">&lt;command-221209454811737&gt;</span> in <span class="ansi-cyan-fg">plot_radar</span><span class="ansi-blue-fg">(df, target_names)</span>
# <span class="ansi-green-intense-fg ansi-bold">     15</span>                                     r<span class="ansi-blue-fg">=</span>avg_df<span class="ansi-blue-fg">.</span>loc<span class="ansi-blue-fg">[</span>i<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">.</span>values<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">     16</span>                                     theta<span class="ansi-blue-fg">=</span>avg_df<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-fg">---&gt; 17</span><span class="ansi-red-fg">                                     </span>fill<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;toself&#39;</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">     18</span>                                     name<span class="ansi-blue-fg">=</span>target_names<span class="ansi-blue-fg">[</span>i<span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">     19</span>                                     showlegend<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">True</span><span class="ansi-blue-fg">,</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;list_updatemenus&#39; is not defined</div>

# %%
cols = df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cols
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[86]: Index([&#39;X_Minimum&#39;, &#39;X_Maximum&#39;, &#39;Y_Minimum&#39;, &#39;Y_Maximum&#39;, &#39;Pixels_Areas&#39;,
#        &#39;X_Perimeter&#39;, &#39;Y_Perimeter&#39;, &#39;Sum_of_Luminosity&#39;,
#        &#39;Minimum_of_Luminosity&#39;, &#39;Maximum_of_Luminosity&#39;, &#39;Length_of_Conveyer&#39;,
#        &#39;TypeOfSteel_A300&#39;, &#39;TypeOfSteel_A400&#39;, &#39;Steel_Plate_Thickness&#39;,
#        &#39;Edges_Index&#39;, &#39;Empty_Index&#39;, &#39;Square_Index&#39;, &#39;Outside_X_Index&#39;,
#        &#39;Edges_X_Index&#39;, &#39;Edges_Y_Index&#39;, &#39;Outside_Global_Index&#39;, &#39;LogOfAreas&#39;,
#        &#39;Log_X_Index&#39;, &#39;Log_Y_Index&#39;, &#39;Orientation_Index&#39;, &#39;Luminosity_Index&#39;,
#        &#39;SigmoidOfAreas&#39;, &#39;cluster_kmeans&#39;, &#39;cluster_agg_clust&#39;,
#        &#39;cluster_f_agg_clust&#39;],
#       dtype=&#39;object&#39;)</div>
